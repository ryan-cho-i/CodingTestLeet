# %%
points = [[1,1], [1,2],[2,1]]

# %%
def minArea(points) :

    minX = float('inf')
    maxX = -float('inf')
    minY = float('inf')
    maxY = -float('inf')

    for x, y in points:
        minX= min(x, minX)
        maxX= max(x, maxX)
        minY= min(y, minY)
        maxY= max(x, maxY)
    
    return (max(maxX-minX+2, maxY-minY+2)) ** 2

# %%
minArea(points)
# Out:
# 1 2 1 2
# 9

# %%
def minArea(x, y, k):

    pair = []
    ans = float('inf')

    for i in range(len(x)):
        pair.append((x[i], y[i]))
    
    pair.sort(key=lambda tup: tup[0])
    
    for i in range(len(x) - k + 1):
        minX = float('inf')
        maxX = -float('inf')
        minY = float('inf')
        maxY = -float('inf')
        for j in range(i, i+k):
            minX = min(minX, pair[j][0])
            maxX = max(maxX, pair[j][0])
            minY = min(minY, pair[j][1])
            maxY = max(maxY, pair[j][1])
            
        ans = min(ans, max(maxX-minX, maxY-minY) + 2)
        
    pair.sort(key=lambda tup: tup[1])
    
    for i in range(len(x) - k + 1):
        minX = 1000000000
        maxX = -1000000000
        minY = 1000000000
        maxY = -1000000000
        for j in range(i, i+k):
            minX = min(minX, pair[j][0])
            maxX = max(maxX, pair[j][0])
            
            minY = min(minY, pair[j][1])
            maxY = max(maxY, pair[j][1])
            
        ans = min(ans, max(maxX-minX, maxY-minY) + 2)
        
    return ans*ans

# %%
r = [586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,516529,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,55816,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,586730,232392,232392,294503]

# %%
r
# Out:
# [586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  586730,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
#  516529,
# ...

# %%
cnt = 0
pre = 0
for num in r :
    if pre == num :
        cnt += 1 
    else:
        print(pre, num, cnt)
        pre = num
        cnt = 1
        
print(cnt)
# Out:
# 0 586730 0
# 586730 516529 69
# 516529 55816 30
# 55816 586730 64
# 586730 232392 125
# 232392 294503 2
# 1

# %%
from collections import Counter

Counter(r)
# Out:
# Counter({586730: 194, 516529: 30, 55816: 64, 232392: 2, 294503: 1})

# %%
a = ['a','b','c','d']
b = [1,2,3,4]

# %%
d=list(zip(a,b))

# %%
set(d)
# Out:
# {('a', 1), ('b', 2), ('c', 3), ('d', 4)}

# %%
set([(1,2),(3,4)])
# Out:
# {(1, 2), (3, 4)}

# %%
node = {'k' : {'d'}}

# %%
seen = {node:1}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 seen = {node:1}
#
# TypeError: unhashable type: 'dict'

# %%
class node ():
    def __init__(self, value = None) -> None:
        self.value = value
        self.next = None
        pass

# %%
n = node(1)

# %%
n.value
# Out:
# 1

# %%
seen = {n:1}
